# %% [markdown]
# # L'impronta semantica degli LLM: Analisi comparativa tra musica reale e artificiale
#
# ### Progetto — corso *Tecnologie dei dati e del linguaggio* (Traccia 3)
# ### Generazione con modello locale + corpus reale via Genius API ufficiale
# **Autore:** _Francesca Bubba_

# %% [markdown]
# ## 1. Domanda di ricerca e ipotesi
#
# **Domanda di ricerca:** un LLM, generando testi di canzoni per generi musicali legati a tradizioni culturali diverse, tende a renderli più simili tra loro (in termini semantici) rispetto a quanto lo siano realmente i testi originali dello stesso genere?
#
# **Ipotesi:** nel corpus reale, i generi musicali restano linguisticamente e tematicamente più distinti tra loro rispetto ai testi generati dal modello, che tendono invece a un maggiore appiattimento reciproco (misurato come similarità semantica più alta tra coppie di generi).

# %% [markdown]
# ## 2. Fonti e dati
#
# **Testi generati:** prodotti da un modello open-weight scaricato da Hugging Face ed eseguito localmente sulla GPU/CPU di Colab — [`Qwen/Qwen2.5-3B-Instruct`](https://huggingface.co/Qwen/Qwen2.5-3B-Instruct), non gated (non richiede account o token Hugging Face).
#
# **Corpus di riferimento (testi reali):** raccolto tramite la [Genius API ufficiale](https://docs.genius.com/) con il pacchetto [`lyricsgenius`](https://pypi.org/project/lyricsgenius/). Richiede un token gratuito, ottenibile registrando un'app su [genius.com/api-clients](https://genius.com/api-clients) (nessun costo, nessuna approvazione manuale). Selezione di partenza di artisti/brani rappresentativi per ciascun genere — da motivare/rivedere criticamente nella relazione.
#
# **Traduzione (normalizzazione multilingue):** libreria [`deep-translator`](https://pypi.org/project/deep-translator/) (nessuna chiave richiesta).
#
# **Strumento per l'analisi semantica:** [`sentence-transformers`](https://www.sbert.net/) (modello multilingue `paraphrase-multilingual-MiniLM-L12-v2`, scaricato pubblicamente senza autenticazione).
#
# **Letteratura di riferimento:**
# - Bender, E. M. et al. (2021). *On the Dangers of Stochastic Parrots.* FAccT.
# - Blodgett, S. L. et al. (2020). *Language (Technology) is Power: A Critical Survey of "Bias" in NLP.* ACL.
#
# **Nota:** un tentativo iniziale di raccogliere i testi reali tramite scraping delle pagine pubbliche di Genius.com è stato abbandonato perché il sito blocca attivamente le richieste automatizzate (errore 403) e i suoi Termini di Servizio vietano lo scraping — da qui la scelta della Genius API ufficiale, gratuita e conforme.

# %% [markdown]
# ## 3. Metodologia — panoramica
#
# 1. Definizione di generi musicali e temi fissi, con un unico prompt per la generazione.
# 2. Generazione dei testi con un modello Hugging Face locale (più ripetizioni per genere/tema).
# 3. Raccolta del corpus reale di riferimento tramite la Genius API ufficiale.
# 4. Preprocessing (pulizia, normalizzazione linguistica tramite traduzione in italiano).
# 5. Calcolo degli embedding semantici e delle matrici di similarità tra generi (generati vs reali).
# 6. Verifica statistica dell'ipotesi (test di Wilcoxon sulle coppie di similarità).

# %%
# Installazione pacchetti necessari (eseguire una sola volta su Colab)
# Suggerimento: Runtime > Cambia tipo di runtime > GPU (T4), per velocizzare la generazione locale.
# !pip install transformers accelerate sentencepiece torch lyricsgenius deep-translator sentence-transformers pandas numpy matplotlib seaborn scipy -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.9 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Caricamento del modello locale (nessuna chiave richiesta)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

MODEL_NAME = "Qwen/Qwen2.5-3B-Instruct"  # modello aperto, non gated: nessun account/token necessario

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",
)
print("Modello caricato su:", model.device)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/35.6k [00:00<?, ?B/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Modello caricato su: cuda:0

# %% [markdown]
# ## 5. Generi musicali, temi e prompt

# %%
GENRES = {
    "trap italiana":    "Italia",
    "pop anglosassone": "USA/UK",
    "reggaeton":        "America Latina/Caraibi",
    "K-pop":            "Corea del Sud",
    "afrobeats":        "Africa occidentale (Nigeria/Ghana)",
    "fado":             "Portogallo",
}

THEMES = ["amore", "festa", "nostalgia"]

N_REPEATS = 3  # generazioni per ogni combinazione genere x tema
# 6 generi x 3 temi x 3 ripetizioni = 54 testi: abbastanza per un test statistico,
# gestibile in pochi minuti anche su GPU T4. Aumenta a 8-10 solo se hai tempo prima
# della lezione (piu dati = risultati piu robusti, ma piu lento da generare).

PROMPT_TEMPLATE = (
    'Scrivi il testo di una canzone {genre} sul tema "{theme}". '
    "Scrivi solo il testo della canzone, senza commenti."
)

# %% [markdown]
# ## 6. Generazione dei testi con il modello locale (versione batch, con cache)
#
# I prompt vengono raggruppati in batch per sfruttare la GPU in parallelo (5-10x più veloce della generazione singola). Inoltre: **se `testi_generati.csv` esiste già** (da un'esecuzione precedente), la cella lo ricarica invece di rigenerare — utile per non dover aspettare di nuovo il giorno della presentazione. Per forzare una nuova generazione, cancella il file o metti `FORZA_RIGENERAZIONE = True`.

# %%
import pandas as pd
import torch
import os

FORZA_RIGENERAZIONE = False  # metti True per rigenerare anche se il CSV esiste gia
PERCORSO_CSV_GENERATI = "testi_generati.csv"

if os.path.exists(PERCORSO_CSV_GENERATI) and not FORZA_RIGENERAZIONE:
    df_generated = pd.read_csv(PERCORSO_CSV_GENERATI)
    print(f"Caricati {len(df_generated)} testi da {PERCORSO_CSV_GENERATI} (nessuna nuova generazione).")
else:
    tokenizer.padding_side = "left"  # necessario per generazione batch con modelli decoder-only
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    BATCH_SIZE = 8  # riduci se vai in errore di memoria GPU (es. a 4)

    def genera_batch(prompts, max_new_tokens=200, batch_size=BATCH_SIZE):
        testi_generati = []
        n_batch_tot = (len(prompts) - 1) // batch_size + 1
        for i in range(0, len(prompts), batch_size):
            batch_prompts = prompts[i:i + batch_size]
            messages_batch = [[{"role": "user", "content": p}] for p in batch_prompts]
            testi_input = [
                tokenizer.apply_chat_template(m, tokenize=False, add_generation_prompt=True)
                for m in messages_batch
            ]
            inputs = tokenizer(testi_input, return_tensors="pt", padding=True).to(model.device)
            with torch.no_grad():
                output = model.generate(
                    **inputs, max_new_tokens=max_new_tokens, do_sample=True,
                    temperature=0.9, top_p=0.9, pad_token_id=tokenizer.pad_token_id,
                )
            lunghezza_input = inputs["input_ids"].shape[1]
            for j in range(len(batch_prompts)):
                testo = tokenizer.decode(output[j][lunghezza_input:], skip_special_tokens=True)
                testi_generati.append(testo)
            print(f"Batch {i // batch_size + 1}/{n_batch_tot} completato")
        return testi_generati

    combinazioni = [
        (genere, tema, i)
        for genere in GENRES
        for tema in THEMES
        for i in range(N_REPEATS)
    ]
    prompts = [PROMPT_TEMPLATE.format(genre=g, theme=t) for g, t, _ in combinazioni]

    testi = genera_batch(prompts)

    records = [
        {"genere": genere, "tema": tema, "ripetizione": i, "prompt": prompt, "testo": testo, "fonte": "generato_llm"}
        for (genere, tema, i), prompt, testo in zip(combinazioni, prompts, testi)
    ]

    df_generated = pd.DataFrame(records)
    df_generated.to_csv(PERCORSO_CSV_GENERATI, index=False)
    print(f"Generati {len(df_generated)} testi e salvati in {PERCORSO_CSV_GENERATI}.")

df_generated.head()
# Out:
# Batch 1/7 completato
# Batch 2/7 completato
# Batch 3/7 completato
# Batch 4/7 completato
# Batch 5/7 completato
# Batch 6/7 completato
# Batch 7/7 completato
# Generati 54 testi e salvati in testi_generati.csv.
#           genere   tema  ripetizione  \
# 0  trap italiana  amore            0
# 1  trap italiana  amore            1
# 2  trap italiana  amore            2
# 3  trap italiana  festa            0
# 4  trap italiana  festa            1
#
#                                               prompt  \
# 0  Scrivi il testo di una canzone trap italiana s...
# 1  Scrivi il testo di una canzone trap italiana s...
# 2  Scrivi il testo di una canzone trap italiana s...
# 3  Scrivi il testo di una canzone trap italiana s...
# 4  Scrivi il testo di una canzone trap italiana s...
#
#                                                testo         fonte
# 0  (Chorus)\nBaby, tu sei l'amore che ho cercato\...  generato_llm
# 1  (Chorus)\nSono in vuoto senza di te\nOra è la ...  generato_llm
# 2  (Preparazione)\n\n[Chorus]\nEccoti l'emozione ...  generato_llm
# 3  (Preparazione) \n\n[Chorus]  \nSotto le luci, ...  generato_llm
# 4  (Chorus)\nSono qua, ho tutto, la festa inizia\...  generato_llm

# %%
# !pip install langdetect -q

import pandas as pd
import os
import re # Required for pulisci_testo
from langdetect import detect # Required for traduci_in_italiano
from deep_translator import GoogleTranslator # Required for traduci_in_italiano

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)  # Mostra anche il testo completo senza tagliarlo

# Define helper functions from cell 9lx-Iif6lHeO to make this cell self-sufficient
def pulisci_testo(testo):
    if not isinstance(testo, str):
        return ""
    t = testo.lower()
    t = re.sub(r"\[.*?\]", " ", t)
    t = re.sub(r"[^\\w\\sàèéìòù']", " ", t)
    t = re.sub(r"\\d+", " ", t)
    t = re.sub(r"\\s+", " ", t).strip()
    return t

def traduci_in_italiano(testo):
    if not isinstance(testo, str) or len(testo.strip()) == 0:
        return testo
    try:
        lingua = detect(testo)
    except Exception:
        lingua = "unknown"
    if lingua == "it":
        return testo
    try:
        # deep-translator ha un limite di caratteri per richiesta: tronchiamo se necessario
        return GoogleTranslator(source="auto", target="it").translate(testo[:4500])
    except Exception as e:
        print(f"Traduzione fallita durante ri-generazione in VB_rktERAvwz: {e}")
        return testo

PERCORSO_CSV_GENERATI = "testi_generati.csv" # Path to original generated texts
PERCORSO_CSV_GENERATI_IT = "testi_generati_it.csv" # Path to cleaned and translated generated texts

# Check if df_generated (the processed one) is defined or its IT CSV exists
if ('df_generated' not in locals() and 'df_generated' not in globals()) or not os.path.exists(PERCORSO_CSV_GENERATI_IT):
    # If not in memory OR IT CSV is missing, try to (re)load and process
    if os.path.exists(PERCORSO_CSV_GENERATI_IT):
        df_generated = pd.read_csv(PERCORSO_CSV_GENERATI_IT)
        print(f"df_generated caricato da '{PERCORSO_CSV_GENERATI_IT}'.")
    elif os.path.exists(PERCORSO_CSV_GENERATI):
        print(f"File '{PERCORSO_CSV_GENERATI_IT}' non trovato. Riprocessando da '{PERCORSO_CSV_GENERATI}'.")
        df_generated = pd.read_csv(PERCORSO_CSV_GENERATI)

        # Re-process if the IT version is missing
        df_generated["testo_pulito"] = df_generated["testo"].apply(pulisci_testo)
        df_generated["testo_it"] = df_generated["testo_pulito"].apply(traduci_in_italiano)
        df_generated.to_csv(PERCORSO_CSV_GENERATI_IT, index=False)
        print(f"df_generated ri-generato e salvato in '{PERCORSO_CSV_GENERATI_IT}'.")
    else:
        print(f"Errore: df_generated non definito e né '{PERCORSO_CSV_GENERATI_IT}' né '{PERCORSO_CSV_GENERATI}' sono stati trovati. Assicurati di aver eseguito le celle precedenti che generano e salvano questo DataFrame.")
        df_generated = None # Ensure df_generated is not referenced if not loaded
else:
    print("df_generated già definito in memoria o caricato con successo dal CSV IT.")

# Display df_generated only if it has been successfully defined/loaded/re-generated
if 'df_generated' in locals() or 'df_generated' in globals():
    if df_generated is not None:
        display(df_generated)
    else:
        print("Impossibile mostrare df_generated perché non è stato caricato o generato.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 20.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done
# File 'testi_generati_it.csv' non trovato. Riprocessando da 'testi_generati.csv'.
# df_generated ri-generato e salvato in 'testi_generati_it.csv'.
#               genere       tema  ripetizione  \
# 0      trap italiana      amore            0
# 1      trap italiana      amore            1
# 2      trap italiana      amore            2
# 3      trap italiana      festa            0
# 4      trap italiana      festa            1
# 5      trap italiana      festa            2
# 6      trap italiana  nostalgia            0
# 7      trap italiana  nostalgia            1
# 8      trap italiana  nostalgia            2
# 9   pop anglosassone      amore            0
# 10  pop anglosassone      amore            1
# 11  pop anglosassone      amore            2
# 12  pop anglosassone      festa            0
# 13  pop anglosassone      festa            1
# 14  pop anglosassone      festa            2
# 15  pop anglosassone  nostalgia            0
# 16  pop anglosassone  nostalgia            1
# 17  pop anglosassone  nostalgia            2
# 18         reggaeton      amore            0
# 19         reggaeton      amore            1
# 20         reggaeton      amore            2
# 21         reggaeton      festa            0
# 22         reggaeton      festa            1
# 23         reggaeton      festa            2
# 24         reggaeton  nostalgia            0
# 25         reggaeton  nostalgia            1
# 26         reggaeton  nostalgia            2
# 27             K-pop      amore            0
# 28             K-pop      amore            1
# 29             K-pop      amore            2
# 30             K-pop      festa            0
# 31             K-pop      festa            1
# 32             K-pop      festa            2
# 33             K-pop  nostalgia            0
# 34             K-pop  nostalgia            1
# 35             K-pop  nostalgia            2
# 36         afrobeats      amore            0
# 37         afrobeats      amore            1
# 38         afrobeats      amore            2
# 39         afrobeats      festa            0
# 40         afrobeats      festa            1
# 41         afrobeats      festa            2
# 42         afrobeats  nostalgia            0
# 43         afrobeats  nostalgia            1
# 44         afrobeats  nostalgia            2
# 45              fado      amore            0
# 46              fado      amore            1
# 47              fado      amore            2
# 48              fado      festa            0
# 49              fado      festa            1
# 50              fado      festa            2
# 51              fado  nostalgia            0
# 52              fado  nostalgia            1
# 53              fado  nostalgia            2
#
#                                                                                                                        prompt  \
# 0          Scrivi il testo di una canzone trap italiana sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 1          Scrivi il testo di una canzone trap italiana sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 2          Scrivi il testo di una canzone trap italiana sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 3          Scrivi il testo di una canzone trap italiana sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 4          Scrivi il testo di una canzone trap italiana sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 5          Scrivi il testo di una canzone trap italiana sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 6      Scrivi il testo di una canzone trap italiana sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 7      Scrivi il testo di una canzone trap italiana sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 8      Scrivi il testo di una canzone trap italiana sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 9       Scrivi il testo di una canzone pop anglosassone sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 10      Scrivi il testo di una canzone pop anglosassone sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 11      Scrivi il testo di una canzone pop anglosassone sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 12      Scrivi il testo di una canzone pop anglosassone sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 13      Scrivi il testo di una canzone pop anglosassone sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 14      Scrivi il testo di una canzone pop anglosassone sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 15  Scrivi il testo di una canzone pop anglosassone sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 16  Scrivi il testo di una canzone pop anglosassone sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 17  Scrivi il testo di una canzone pop anglosassone sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 18             Scrivi il testo di una canzone reggaeton sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 19             Scrivi il testo di una canzone reggaeton sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 20             Scrivi il testo di una canzone reggaeton sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 21             Scrivi il testo di una canzone reggaeton sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 22             Scrivi il testo di una canzone reggaeton sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 23             Scrivi il testo di una canzone reggaeton sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 24         Scrivi il testo di una canzone reggaeton sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 25         Scrivi il testo di una canzone reggaeton sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 26         Scrivi il testo di una canzone reggaeton sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 27                 Scrivi il testo di una canzone K-pop sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 28                 Scrivi il testo di una canzone K-pop sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 29                 Scrivi il testo di una canzone K-pop sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 30                 Scrivi il testo di una canzone K-pop sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 31                 Scrivi il testo di una canzone K-pop sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 32                 Scrivi il testo di una canzone K-pop sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 33             Scrivi il testo di una canzone K-pop sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 34             Scrivi il testo di una canzone K-pop sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 35             Scrivi il testo di una canzone K-pop sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 36             Scrivi il testo di una canzone afrobeats sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 37             Scrivi il testo di una canzone afrobeats sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 38             Scrivi il testo di una canzone afrobeats sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 39             Scrivi il testo di una canzone afrobeats sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 40             Scrivi il testo di una canzone afrobeats sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 41             Scrivi il testo di una canzone afrobeats sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 42         Scrivi il testo di una canzone afrobeats sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 43         Scrivi il testo di una canzone afrobeats sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 44         Scrivi il testo di una canzone afrobeats sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 45                  Scrivi il testo di una canzone fado sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 46                  Scrivi il testo di una canzone fado sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 47                  Scrivi il testo di una canzone fado sul tema "amore". Scrivi solo il testo della canzone, senza commenti.
# 48                  Scrivi il testo di una canzone fado sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 49                  Scrivi il testo di una canzone fado sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 50                  Scrivi il testo di una canzone fado sul tema "festa". Scrivi solo il testo della canzone, senza commenti.
# 51              Scrivi il testo di una canzone fado sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 52              Scrivi il testo di una canzone fado sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
# 53              Scrivi il testo di una canzone fado sul tema "nostalgia". Scrivi solo il testo della canzone, senza commenti.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   testo  \
# 0                                                                                                                                                                                                   (Chorus)\nBaby, tu sei l'amore che ho cercato\nPer tutto questo tempo, ora è la mia vita\nTi sento nelle mie vene, ti vedo in ogni cosa\nNon potrei vivere senza di te\n\nVerse 1:\nSognavo di trovare qualcosa di diverso\nMa il mio cuore era già preso dal tuo gioco\nOra sono qui, in quest'isola di desiderio\nE non voglio tornare indietro più\n\nVerse 2:\nLe stelle brillano al mio fianco\nCome tu nel buio del mio cuore\nNon voglio più nasconderti, mi fai bruciare\nIl tuo calore è il mio rifugio\n\nBridge:\nCi siamo incontrati e ci siamo innamorati\nNon importa dove andremo, non importa come\nSolo il nostro amore, il nostro amore\nSiamo insieme finché non
# 1                                                                                                                                                                                                                                                                    (Chorus)\nSono in vuoto senza di te\nOra è la fine\nDove sei tu il mio amore\n\n(Intro)\nHo messo insieme queste parole\nPer dirti cosa provo a lungo distanza\nHo chiuso gli occhi e ho aspettato\nIn attesa che tu mi abbia davanti\n\n(Refrain)\nSono in vuoto senza di te\nOra è la fine\nDove sei tu il mio amore\nSì sì sì\n\n(Outro)\nE se ti sento dire "non più"\nMi sciolgo come neve al sole\nNon capisco l'ira o le lacrime\nSolo la tua mancanza mi tormenta\n\n(Chorus)\nSono in vuoto senza di te\nOra è la fine\nDove sei tu il mio amore\n\n(Outro)\nSiamo sempre stati il fulmine\nMa ora non so
# 2                                                                                                                                                                                                                                                                                       (Preparazione)\n\n[Chorus]\nEccoti l'emozione in un ritmo scelto\nCade l'amore come neve che cade\nSul mio cuore, mi stai colmando\nAmore, è tutto ciò che ho\n\n(Esatto)\nQuando le luci si spengono e la musica diventa la voce\nIn questi corridoi, io ti cercherò\nRaggiungi il mio cuore, dove l'amore cresce\nAmore, mi hai preso tutto\n\n[Chorus]\nEccoti l'emozione in un ritmo scelto\nCade l'amore come neve che cade\nSul mio cuore, mi stai colmando\nAmore, è tutto ciò che ho\n\n(Duetto)\n(Tua voce)\nSei l'alba, sei il tramonto, sei l'istante perfetto\n(Altri)\nMi hai reso
# 3                                                                                                                                                                                                                                                                 (Preparazione) \n\n[Chorus]  \nSotto le luci, la festa s'incende  \nCerchi d'oro tra le ombre, la notte è mia  \nCon gli amici in un pool  \nLa musica che sale fino al cielo\n\n[Refrain]  \nEcco la festa, ecco l'amore  \nIn questo momento tutto è possibile  \nNon sento più il mio cuore  \nSolo voglia e puro bisogno\n\n[Intermezzo]  \nDi ballare, di sognare e di vivere  \nIl tempo passa ma i ricordi restano\n\n[Chorus]  \nSotto le luci, la festa s'incende  \nCerchi d'oro tra le ombre, la notte è mia  \nCon gli amici in un pool  \nLa musica che sale fino al cielo\n\n[Refrain]  \nEcco la festa
# 4                                                                                                                                                                                                                                  (Chorus)\nSono qua, ho tutto, la festa inizia\nQuando la luna illumina questo momento\nCazzo, questa sera non c'è un posto migliore\nChe starmene qua con te, e godere\n\nVerse 1:\nLe luci che danzano con le parole\nDi chi ha la pelle scura o bianca come il latte\nQueste note vengono da dentro il cuore\nMa sento che stanno uscendo dalla mia voce\n\nVerse 2:\nLa gente balla, io resto qui\nGuardando l'oceano di persone che mi fanno bene\nTutti siamo soli, tutti siamo pieni\nDi emozioni, di musica, di sogni\n\n(Chorus)\nSono qua, ho tutto, la festa inizia\nQuando la luna illumina questo momento\nCazzo, questa sera non c'è un
# 5                                                                                                                                                                                                                                       (Refrain)\nSotto la luna, sotto le luci che bruciano,  \nsiamo un gruppo di ragazzi a festeggiare,  \nognuno ha un segreto, ma non lo nascondiamo,  \nsiamo qui per vivere questa serata.\n\n(Duetto)\nDove stanno i nostri amici? Sono là fuori,  \ntra gli spari e i discorci,  \nsi stanno divincolando per essere con noi,  \ne la festa è ancora più grande.\n\n(Tempo)\nEcco il gioco, ecco il party,  \nnon ci sono regole, solo il desiderio,  \nlì dentro, il cuore batte forte,  \ncome una pulsazione senza fine.\n\n(Refrain)\nSotto la luna, sotto le luci che bruciano,  \nsiamo un gruppo di ragazzi a festeggiare,  \nognuno ha
# 6                                                                                                                                                                                                                                                                                               (Capitolo 1)\nVibra l'antiquato stereo,  \nfumo di sigarette soffocata,  \nnostalgia che si fa vapore.\n\n(Singhiozzo)\nSulla scena la luce azzurra,  \nsotto quel cielo bianco e vuoto,  \nlontano il mio piccolo porto.\n\n(Canto)\nL'oceano ha parlato a me,  \ndelle tue labbra e dei tuoi abbracci,  \ndi quelle notti in cui le stelle erano più brillanti.\n\n(Canto)\nOre perdute, sogni smarriti,  \nl'attesa, il desiderio,  \ndi un luogo lì, un tempo lì.\n\n(Sinfonia)\nLa città è cambiata, i luoghi sono dimenticati,  \nma dentro di me, la tua voce rimane,  \nnostalg
# 7                                                                                                                                                                                                                             (Preziosa è la tua nostalgia)\nLa città che mi hai conosciuto\nSul marciapiede, sotto l'arcata\nLe storie si nascondevano tra i muri\n\n(Preziosa è la tua nostalgia)\nNel profumo dei gelati\nSotto il sole di un pomeriggio d'inverno\nLa mia adolescenza sussurrava i tuoi nomi\n\n(Preziosa è la tua nostalgia)\nLontana ora ma sempre presente\nI ricordi che non voglio lasciare andare\nE il cuore che batte per i giorni lontani\n\n(Preziosa è la tua nostalgia)\nQuando guardo dentro di me\nRicordo le tue labbra, il tuo sorriso\nOra lontane, sempre vicine\n\n(Preziosa è la tua nostalgia)\nNon riesco a cancellare\nIl suono del tuo pass
# 8                                                                                                                                                                                                                                                (Tyler)\nDove le luci sono sempre accese\nE i nostri sogni brillano più chiaro\nC'è la gente che si diverte\nSulle scale, sotto i neon\n\n(Refrain)\nNostalgia, nostalgia\nChe ricordi mi porti con te\nOgni sera, ogni pomeriggio\nRipenso ai momenti che ho perso\n\n(Duetto)\nNostalgia, nostalgia\nChe ricordi mi porti con te\nOgni sera, ogni pomeriggio\nRipenso ai momenti che ho perso\n\n(Lyrics Solo)\nDi quelle serate, di quei cantieri\nQuando il tempo sembrava rallentare\nQuando la vita era un gioco\nChe non avevo mai visto così bello\n\n(Refrain)\nNostalgia, nostalgia\nChe ricordi mi porti con te\nOgni sera,
# 9                                                                                       (Chorus)\nUnderneath the stars we meet\nIn this moment we find our feet\nAnd in your eyes, my heart soars\nIn this love, I'm found at last\n\n(Verse 1)\nThe world's a blur when you're around\nEvery fear fades with your sound\nI never thought to find so much\nIn just your touch, your smile, and your talk\n\n(Chorus)\nUnderneath the stars we meet\nIn this moment we find our feet\nAnd in your eyes, my heart soars\nIn this love, I'm found at last\n\n(Bridge)\nThrough all the laughter and the tears\nOur hearts have grown so dear\nTogether, we can conquer all\nWith hands held tight and hearts galloping\n\n(Verse 2)\nI used to think it was too good\nTo be true, that love would just undo\nBut here, I see the magic unfold\nIn your arms, I've found my world anew\n\n(
# 10                                       In the quiet of your dreams,\nLies a love that I can't hide.\nWith every beat of my heart,\nI feel the way you make me feel.\n\nThrough the laughter, through the tears,\nOur story is written clear.\nEvery moment in our lives,\nIs filled with love's pure fire.\n\nWhen the night falls and the stars twinkle,\nI see a future just for you and me.\nWith every breath we take,\nWe dance in love's embrace.\n\nOh, let us walk this road together,\nHand in hand, side by side.\nFor in your arms I find my peace,\nAnd in your eyes I find my pride.\n\nNo matter what the world may say,\nOur love is strong and true.\nIt'll stand the test of time,\nAs long as we hold on, we're secure.\n\nSo here's to love, sweet and bold,\nTo the moments we both adore.\nLet us cherish this day forever,\nTill the end of time, love is ours.
# 11          (Title: "Together Through the Storms")\n\nVerse 1:\nEvery heart has its own song\nSometimes it's hidden in the fog\nWhen love starts to grow\nIt finds its way through the gloom\n\nChorus:\nTogether through the storms\nThrough the highs and the lows\nWe hold hands as we stand strong\nAnd let our hearts be shown\nIn the darkest of the night\nOur flames never quite die\nFor love is all we need to guide us\nIn the journey of life\n\nVerse 2:\nThere's a fire that burns deep within\nAnd it guides us when we feel blind\nThrough the ups and the downs\nIt brings us closer around\n\n(Chorus)\nTogether through the storms\nThrough the highs and the lows\nWe hold hands as we stand strong\nAnd let our hearts be shown\nIn the darkest of the night\nOur flames never quite die\nFor love is all we need to guide us\nIn the journey of life\n\nBridge:\n
# 12                                                         (Chorus)\nLight up the night, let the music play\nFeel the beat, in this moment we're alive\nLost in the crowd, under the moon and stars\nFestivities never end, tonight is ours to claim\n\n(Verse 1)\nWe gather 'round the fire, under a starry sky\nEach face a story, each laugh a sign\nThe rhythm of our hearts, it speaks for itself\nTonight's the night we celebrate everything\n\n(Chorus)\nLight up the night, let the music play\nFeel the beat, in this moment we're alive\nLost in the crowd, under the moon and stars\nFestivities never end, tonight is ours to claim\n\n(Bridge)\nWine flows like rivers, through the darkened hall\nMemories made, with every song that plays\nIn every dance, love finds its way\nThis is where dreams come true, in the glow of the flame\n\n(Verse 2)\nThe air is thick
# 13                                               Here we are, under the big old tree\nWhere the stars come out to play\nLet's raise a glass, and dance away\nAt this wild and happy spree\n\nWe're all here tonight, just for one night\nNo more worries, no more fight\nSo let's raise a toast, and make it right\nAnd forget our troubles tonight\n\nThe DJ is spinning tunes that make us sway\nThe music fills the air with joy\nIt's like we're all part of something rare\nA moment that feels brand new and so bright\n\nCome on, let's have some fun, let's get loose\nLet the rhythm guide us, let's not be too proud\nWe'll spill the drinks and sing along loud\nThis party's got a heart that won't stop\n\nWe're here to celebrate, we're all on the same page\nNo need to care about the price\nOf love or hate, or anything else we've had to face\nCause now we're here
# 14                                                                     (Chorus)\nLet's raise a glass and let the music play\nFeel the beat and feel it all alive\nThe party's just begun, so let's not be late\nLet's make this night forever stay\n\n(Verse 1)\nThrough the streets, the lights are shining bright\nThe world is here to dance and shout\nWith every step we take tonight\nWe're free from worry, no more fright\n\n(Bridge)\nSo come on, let's not hold back\nLet's light up the darkest of the night\nLet's spill the drinks, sing loud and free\nThis moment in time, we'll never see\n\n(Chorus)\nLet's raise a glass and let the music play\nFeel the beat and feel it all alive\nThe party's just begun, so let's not be late\nLet's make this night forever stay\n\n(Verse 2)\nThe sun will set, the stars will appear\nAnd we'll still be here, with the night
# 15                                       (Chorus)\nOh, it's in the air, a feeling deep,\nIn every corner, we see the memories sweep.\nThrough the shadows, through the light,\nOf a time long gone but never right.\n\nVerse 1:\nOn the cobblestone streets where we used to run,\nThe laughter echoes, now far from done.\nThe smell of old rain and fresh cut hay,\nWhispers of summers that are not here today.\n\nChorus:\nOh, it's in the air, a feeling deep,\nIn every corner, we see the memories sweep.\nThrough the shadows, through the light,\nOf a time long gone but never right.\n\nBridge:\nThe city's changed, yet still it calls me home,\nA place I can't leave, or I won't be home anymore.\nI walk down the path where we used to play,\nFeeling the nostalgia, like an old, sweet day.\n\nVerse 2:\nThe taste of hot dogs at our favorite diner,\nAnd how the sun
# 16                                                Streets where my heart used to roam\nThrough alleys I wandered alone\nEvery trace of time that's gone\nLeaves me yearning for a home\n\nI see the faces from the past\nWhere laughter and tears were cast\nThe warmth of memories that last\nFades with each day of the last\n\nThe city lights that guide me through\nEchoes of a bygone crew\nIn every corner, there's a clue\nOf times when we knew\n\nNow I'm walking down these streets\nA stranger in the old places' seats\nThe past is like a river fleet\nAnd now it's gone, it's left me to weep\n\nThe shops, the parks, they all remind\nHow fast life's course can spin\nBut in my soul, they still align\nTo those golden hours of the mind\n\nSo I sing this song to you\nA melody of love and you\nFor though the years have flown so sure\nYou're always in my heart
# 17                                    (Chorus)\nOh, it was so long ago\nThe world seemed just like a dream\nI remember those sweet times\nWhen life was young and kind\n\n(Verse 1)\nIn the old photo frames you hung,\nA world of love and fun\nThe laughter of the children in the yard\nAnd the stars above so grand\n\n(Pre-Chorus)\nThose days have slipped away\nNow shadows of that past\nA memory I hold dear\nYet I feel the distance too near\n\n(Chorus)\nOh, it was so long ago\nThe world seemed just like a dream\nI remember those sweet times\nWhen life was young and kind\n\n(Bridge)\nThrough the mist of time's long trail\nWe see our footsteps made\nThough we cannot turn back now\nThere's still something to be found\n\n(Chorus)\nOh, it was so long ago\nThe world seemed just like a dream\nI remember those sweet times\nWhen life was young and kind\n\n(
# 18                                                                                                                                                                                                           Aquí va el texto de una cancion Reggaeton sobre amor:\n\n(Preludio de batería)\nEn la pista de baile, los ojos se encuentran  \nSonrisas de pura felicidad, corazones danzan con alegría  \nCada paso te dice que estoy aquí para ti\n\n(Refrón)\nAmor, amor, es como una canción sin fin  \nAmor, amor, cuando estás cerca, el mundo se vuelve tan bonito\n\n(Sección principal)\nLuz de luces, ritmo en cada pieza de música  \nCada noche, tú y yo, somos los reyes del universo\nTu risa es mi melodía, tu mirada, mi ritmo\nCuando estamos juntos, la vida se siente especial\n\n(Refrón)\nAmor, amor, es como una canción sin fin  \nAmor, amor, cuando estás cerca,
# 19                                                                                                                                                                                                                                                    [Chorus]\nAmor mio, amor mío, amor mío\nEn el ritmo del reggaeton, la vida es un sueño\nLa noche es nuestro teatro, bailando al son de los beats\nEn tus ojos, mi corazón se va volando\n\n[Pre-Chorus]\nTu risa, mi fiesta\nTu abrazo, mi alivio\nEn ti me siento completo\nEso lo sabes, no necesito más\n\n[Corruga]\nAmor mio, amor mío, amor mío\nEn el ritmo del reggaeton, la vida es un sueño\nLa noche es nuestro teatro, bailando al son de los beats\nEn tus ojos, mi corazón se va volando\n\n[Titoli]\nDe día en la cama, de noche en el sofá\nContigo es como si el mundo no estuviera\nNuestro amor, como una canc
# 20                                                                                                                                                                                                       Aquí va el texto de una canción Reggaeton sobre el tema "Amor":\n\n(Chorus)\nAmor, oh amor, que sabor tuya,\nTe miro, me adentro y no quiero salir.\nCuando estás cerca, el tiempo se detiene,\nNada más importa que tu caricia.\n\n(Refrain)\nPulsa el play, enciende la luz,\nDale un beso, deja que las emociones salgan.\nTu risa es mi melodía, tu cuerpo es mi ritmo,\nNo importa lo que digan, el amor es mi combustible.\n\n(Chorus)\nAmor, oh amor, que sabor tuya,\nTe miro, me adentro y no quiero salir.\nCuando estás cerca, el tiempo se detiene,\nNada más importa que tu caricia.\n\n(Bridge)\nNo quiero dejar contigo ni un momento,\nMi corazón late por ti,
# 21                                                                                                                                                                                             (Prepara la pista)\nVamos al parque, vamos al parque\nEs hora de bailar, es hora de bailar\nCon amigos y familia, sin preocupaciones\n¡Llevemos la fiesta hasta las estrellas!\n\nMamá te vea no importa si es tarde\n¡Que la noche es nuestra, es nuestra!\nSí, sí, sí\n¡Qué lindo que estamos, que estamos!\n\nCambia la ropa, cambia la música\nNo hay límites para la diversión\nVamos, vamos, vamos\n¡Que la fiesta nunca acabe, nunca acabe!\n\nPonle ritmo a tu vida, ponele color\n¡Nada importa la edad, nada importa la edad!\nVamos al parque, vamos al parque\nEs hora de bailar, es hora de bailar\nCon amigos y familia, sin preocupaciones\n¡Llevemos la fiesta hasta las
# 22                                                                                                                                                                                                          ¡Hey, vamos a bailar! Ven conmigo,\nLa pista está llena de rumberos.\nEl ritmo, tan caliente, nos trae al ritmo del viento,\nEn la noche, la música nos lleva al cielo.\n\n¡Ay, esta noche es nuestra,\nNo hay nadie más que nos acompañe!\nEsto es el reggaetón, es la fiesta,\nCada uno en su lugar, pero todos unidos.\n\n¡Bailando con el viento y la luna!\nLas caras iluminadas, los corazones latiendo,\nEn este momento, no importa quién eres,\nSomos una familia, en la pista juntos.\n\n¡Vamos a cantar, vamos a bailar,\nEste es nuestro espacio, nuestro reino!\nEl baile, la risa, las risas,\nEsta noche, en la fiesta, estamos vivos.\n\n¡A por la noche, a
# 23                                                                                                                                                                                                                            ¡Ven aquí, ven aquí! Sí, hoy es fiesta\nVamos a bailar, vamos a perder la cuenta\nLlega que no hay noche para ser mala\n¡Sigue, sigue la fiesta!\n\n¡Qué rico el sonido de los tambores!\nLa música va creciendo, ¡ya sabes!\nLas luces se van apagando, todo va oscureciendo\n¡El amor fluye como el vino!\n\nTe miro en los ojos y veo el deseo\nEstamos perdidos en este ritmo tan loco\nNo somos más que dos cuerpos en un baile\n¡Y la noche parece que no tiene fin!\n\n¡A por ese último trago! No te olvides\nDe esa promesa que hicimos, ¿te acuerdas?\nVivamos intensamente, sin preocuparnos\n¡Es la vida, no es una cita!\n\n¿Qué tal si segu
# 24                                                                                                                                                                                                                       (Preludio)\nCantaré sobre los días de antes\nCuando el sol nacía como envidia\nY la noche era un secreto de amores\n\n(Interludio)\nRecuerdo tu risa que nunca se fue\nEn cada rincón, en cada sueño\nNostalgia de ese amor que aún duerme\nEn cada sonrisa, en cada desayuno\n\n(Presto)\nEn las calles, las canciones, los bailes\nEran tiempos de fiesta, de alegría sin límites\nNostalgia de esos pasos, esos ritmos\nQue ahora danzan con mis recuerdos\n\n(Desdichado)\nY cuando la noche cae y las luces se apagan\nLos sentimientos vuelven a brillar con luz propia\nNostalgia, nostalgia de aquellos momentos\nDonde el reggaetón era todo\n\n(Trío
# 25                                                                                                                                                                                                                                                                    [Preziosa, oh preziosa]\nLa noche es mía\nVoy a recordar el pasado\n\n[Clic, clic, clac]\nLa ciudad está tan tranquila\nParece que todo estuvo bien\n[Tiempo de nostalgia]\n\n[Mambo, mambo, mambo]\nEn la calle me encontré con alguien\nRecuerdos de una época antigua\n[Regresa el calor]\n\n[Rey, rey, rey]\nNostalgia en mis venas\nEs un viento suave que siento\n[Regresa el ritmo]\n\n[Clic, clic, clac]\nCada pasillo me recuerda\nEl calor de los días\n[Recordando]\n\n[Mambo, mambo, mambo]\n¿Te acordaste de los amores?\nDe aquella danza de amor\n[Recuerdos]\n\n[Rey, rey, rey]\nNostalgia en mis
# 26                                                                                                                                                                                                                                          Voci d'amore che si spegneranno\nNella notte e nel sole\nQuando il tempo si fa lento e sospeso\nE le nostre storie diventano lontane\n\nQuelle ore che sembravano infinite\nOra sono passate come fumo\nI ricordi mi stringono forte come un abbraccio\nE non riesco a scuotersi\n\nRisate che risuonano nelle orecchie\nCanticchiare canzoni del passato\nE ricordare le stelle che brillavano\nDavanti ai nostri occhi\n\nI tuoi capelli che danzano al vento\nLa tua voce che risuona ancora\nI momenti che sono passati come un'eternità\nMa ora sembra che tutto sia inutile\n\nIl mio cuore ha bisogno di qualcosa di caldo\nPer risc
# 27                                                                                                                                                                                                                                                                                      (Chorus)\nAmor é luz que me guia, tu és o farol no mar\nSob o céu escuro, vozes que ecoam\nO teu sorriso dança, e eu sigo em frente\nNo teu olhar, encontro a paz\n\n(Verse 1)\nSonhos se misturam, num abraço de sonho\nCorações batem juntos, sem medo do frio\nO teu beijo é um navio que navega\nAo longe da praia, onde o amor se forma\n\n(Bridge)\nÉ um rio que corre, entre o sol e as nuvens\nE tu és o barco que segura, no meio das ondas\nÉ um misterioso navio, em busca de portos\nNo coração, encontro a porta secreta\n\n(Chorus)\nAmor é luz que me guia, tu és o farol no mar
# 28                                          Titolo: Heartbeat Melody\n\nVerse 1:\nIn the moonlit garden, your smile so bright,\nWhispers in the wind, of love's untold night.\nEvery step I take, under your starry sky,\nFeels like home, where my heart finds its fly.\n\nPre-Chorus:\nThrough the rain or shine, your hand I hold,\nGuiding me through each stormy old.\nYour laughter, it dances in the melody,\nOf our story, that's just beginning.\n\nChorus:\nHeartbeat melody, in the rhythm of time,\nLove's journey, it's the most sublime.\nHand in hand, we'll dance in the night,\nIn this world, together, we'll fight.\n\nVerse 2:\nUnder the city lights, as shadows dance,\nYou're shining bright, beyond compare.\nOur love is pure and wild, an endless sea,\nIn the melody of our hearts, it's clear.\n\nPre-Chorus:\nThrough the highs and lows, your heart stays
# 29                                                                                                                                                                                                                                                       (Chorus)\nAmore, come il sole che risplende\nAmore, come il mare che sussurra\nAmore, in ogni braccio teso\nAmore, in ogni cuore che berra\n\n(Verse 1)\nSogni e risate, dentro di noi si uniscono\nIl tuo sorriso, è la luce che mi illumina\nTi stringo forte, nel buio della notte\nCome una promessa, per sempre io ti porterò\n\n(Chorus)\nAmore, come il sole che risplende\nAmore, come il mare che sussurra\nAmore, in ogni braccio teso\nAmore, in ogni cuore che berra\n\n(Verse 2)\nLe parole mie, come le note di una canzone\nTu sei il mio ritmo, nel mondo intero\nCon te non sento più la tua mancanza\nIl tuo
# 30                                                                                                                                                                                                                                                                     (Chorus)\nLuminose luci, danza con il vizio\nRisate, balli, e la musica non smette mai\nSogna dietro occhiali, sorridi e brilla\nIn questa festa, siamo stelle senza fine\n\n(Bridge)\nNessun limite, nessun prezzo per il momento\nI nostri cuori in un bacio che non termina\nIl tempo è solo una linea sulla scena\nCi abbracciamo, e sogni si fondono\n\n(Chorus)\nLuminose luci, danza con il vizio\nRisate, balli, e la musica non smette mai\nSogna dietro occhiali, sorridi e brilla\nIn questa festa, siamo stelle senza fine\n\n(Outro)\nNon smetteremo mai di ballare\nNel buio, nel chiaro di luna\n
# 31                                                                 (Drumbeat)\n\n(Pre-Chorus)\nLights shining bright in the night\nMusic swaying, bodies in flight\nFestive air fills the night\nDance with me, let's go tonight\n\n(Chorus)\nLet's celebrate, tonight we'll shine\nThrowing back drinks and laughing till we're divine\nThe party never ends, just keep on going\nTonight, it's all about the fun\n\n(Verse 1)\nFrom dusk till dawn, the night won't end\nLaughter, joy, and dance, oh what a scene\nThe moon above, guiding us tonight\nWith every beat, we feel the light\n\n(Pre-Chorus)\nLights shining bright in the night\nMusic swaying, bodies in flight\nFestive air fills the night\nDance with me, let's go tonight\n\n(Chorus)\nLet's celebrate, tonight we'll shine\nThrowing back drinks and laughing till we're divine\nThe party never ends, just keep
# 32  (Chorus)\nSinging under the moon, dancing till the morning light,\nUnder the starry sky, we're one big party tonight.\nWe're having the time of our lives, no regrets, just pure fun,\nIn this moment, everything feels brand new.\n\n(Verse 1)\nThe DJ's spinning, the tunes get better with each spin,\nLaughter fills the air, the night is in the line,\nEvery face lit up like a Christmas tree,\nIn this world of ours, there’s no better feeling to be free.\n\n(Chorus)\nSinging under the moon, dancing till the morning light,\nUnder the starry sky, we're one big party tonight.\nWe're having the time of our lives, no regrets, just pure fun,\nIn this moment, everything feels brand new.\n\n(Bridge)\nSo let the music play, let the drinks flow freely,\nWe chase the stars tonight, with dreams that won't tire,\nThis is the moment when every doubt fades away
# 33                                                                                                                                                                                                                            (Prezzyzzzzz)  \n(Perfetto)\n\nYoongi:  \nLuna soleggiata si è tramutata in una luna di neve  \nLa mia città amata ora diventa un ricordo lontano  \nRicordi che brilla come stelle in cielo sereno  \nQuando tutto è passato, i ricordi restano qui\n\nJungkook:  \nLe strade vecchie sono diventate traioli di nostalgia  \nI colori dell'estate si sono trasformati in un'immagine  \nCose semplici come il profumo della fogna divennero un tesoro  \nOgni angolo ha il suo ricordo\n\nMinju:  \nPensieri confusi si mescolano con le lacrime  \nIn questo mondo senza il mio posto  \nUn canto dolce di un tempo mi riecheggia nel cuore  \nSogni sv
# 34                                                             (Chorus)\nWish upon a star, in the night so bright\nMemories like old friends, come back to light\nOh, nostalgia, oh what a journey it is\nTo a time when everything seemed so right\n\n(Verse 1)\nRaindrops on my windowpane, a story to tell\nWhispers of a summer that we both will relive\nIn that park where we first met, under the moon's spell\nThe scent of jasmine and the feel of your hand\n\n(Verse 2)\nEchoes of laughter, in the soft glow of the firelight\nThose moments we shared, they still linger like a light\nEvery memory, every tear, a part of our heart\nThe good times, the bad times, they made us so much stronger\n\n(Bridge)\nWe danced under the stars, without any care\nLost in each other's eyes, in the quiet of the air\nBut now we're apart, the distance between us grows\nAnd I
# 35                                                                                                                                                                                                                                                       (Prolog)\nErase umana, era gioiosa\nRisate e carezze, erano preziosi\n\n(Prima Stanza)\nIn un paesaggio di fiamme dorata,\nNostalgia per i giorni che volarono\nCrescendo come un bosco, le stelle brillarono\nMa ora, soli rimangono, le ombre scomparvero\n\n(Seconda Stanza)\nLa città è cambiata, ora si chiama vuota\nPercorsi vecchi, ora solo traccia di passi\nIl cuore batte veloce nel mio petto\nCome il vento che porta il ricordo\n\n(Terce Stanza)\nLe foglie cadute sotto i miei piedi\nIl suono delle note nell'aria\nTutti gli oggetti che mi avevano tenuto compagnia\nOra sono soli, la nostalgia mi ha inv
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Amoré, oh amoré\nNa mën ni dëgg yu péyi\nNa mo gée, na mo zé\nMo taa fii àwùdìnìn àwùdìnrin\n\nGwi, gui\nGwi, gui\n\nWaaye, waaye\nYàyì àwùdìnrin fii\nWu kò lèyìn\nÀwùdìnrin mo\n\nNí àwùdìnrin tó wá\nNa wú òkùn ní péyi\nWaaye, waaye\nNí àwùdìnrin tó wá\nNa wú òkùn ní péyi\n\nMo taa nín\nMàà fún tó wá\nMo taa nín\nBàsàn tó bùkàn\n\nSì àwùdìnrin mo\nNa mú
# 37                                                                                                                                                                                                                                                                                                                                                                             (Strofa 1)\nAmorim na amorim, oh, amorim na amorim  \nSangoma na sangoma, oh, sangoma na sangoma  \nGuede na guede, oh, guede na guede  \nMandinka na mandinka, oh, mandinka na mandinka\n\n(Preghiera)\nYenke mmoji wọn ni nipa amonu  \nNkan na gbadugudu, oh, nkan na gbadugudu  \nNkan na gbedegbuda, oh, nkan na gbedegbuda  \nIbe nkan na gbedegbuda, oh, ibe nkan na gbedegbuda\n\n(Strofa 2)\nEjuru na ejuru, oh, ejuru na ejuru  \nAse na ase, oh, ase na ase  \nIbe na iye, oh, iye na iye  \n
# 38                                                                                                                                                                                                                                              Amor é na noite de lua che canta\nCantando amor, cantando lua\nCaminhando na luz que brilha\nNoites longas, dias curtos, coração acelerado\n\nÉ amor que me faz sentir leve\nFaz meu corpo dançar, sem medo\nE os olhos que brilham como estrelas\nSão o prazer de estar contigo\n\nNas músicas do meu coração\nRepetindo essa balada\nAlegria em cada batida do meu coração\nCanta o amor, canta a lua\n\nSobre as águas que correm\nE o vento que sopra\nSão mensageiros da paixão\nQue você e eu compartilhamos\n\nAmor é o farol que guia\nNa escuridão da noite\nEle é minha companheira\nEnquanto eu me deslizo nas ondas do amor
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Ebi iyanu n'ibiti\nSida oye torunsi a ti gbo\nOjude sọ wa, ṣugbọn ẹni pe ẹkọlọ\nṢe pataki mi ni lati gba ọ̀kan pe o dara\n\nEyi jẹ siyàn àṣà\nẸgbẹ́ lè pataki, wá láti pe\nGẹ̀ẹ́sí ní ìwé ènìyàn láti kókó pé\nẸ̀kọ̀lọ́ jẹ́ rẹ̀ sí yọ pé ẹgbẹ́ kò lára\n\nṢùgbọ́n àláṣẹ̀ lati pe\nWá láti pe kò lẹ̀ láti ń fi\nỌ̀kan tún tọ̀ fẹ́ ọ̀kan\nṢùgbọ́n
# 40                                                                                                                                                                                                                                                                                                                                                                                           (Lyrics)\n\nEbi oye naa ohane ohane\nEbi oye naa ohane ohane\nLalala la la la\n\nEbi oye naa ohane ohane\nEbi oye naa ohane ohane\nLalala la la la\n\nDance oye naa ohane ohane\nDance oye naa ohane ohane\nDance oye naa ohane ohane\n\nYeye yeye naa ohane ohane\nYeye yeye naa ohane ohane\nYeye yeye naa ohane ohane\n\nAye aye naa ohane ohane\nAye aye naa ohane ohane\nAye aye naa ohane ohane\n\nSaba naa naa naa\nSaba naa naa naa\nSaba naa naa naa\n\nNana naa naa naa\nNana na
# 41                     (Dance the night away with me)\nLet's celebrate tonight, feel the vibe\nUnder the stars we shine like diamonds, shining bright\n(Music flows like rivers, dance moves like tides)\nFeel the rhythm, let your worries disappear\nJump and shout, let's make this moment last forever\n\n(Sounds of drums, beats that won't stop)\nWe're on our way to heaven, the party is on its way\n(Feel the music, let it take control)\nDance to the beat, let the energy ignite\n(Take the risk, just let go, and let the world go)\nLet's break down those barriers, and let the music guide us\n\n(In the clubs, under the moon)\nThis is where our spirits rise, no one can hold us down\n(Let's make memories, till the dawn breaks free)\nUnderneath the sky, we'll dance until morning\n(Hold hands tight, let love bloom like flowers in bloom)\nIn this night, let
# 42                                                                                                                                                                                                       (Preludio su uma melodia leve e nostalgica)\n\nÉ na noite que eu penso\nSobre aqueles dias de pura alegria\nSobre a nossa juventude brilhante\nOnde a vida parecia eterna\n\nÉ nas sombras do meu quarto\nQue os sonhos voltam pra mim\nSonhos dos tempos passados\nDe quando eu ainda tinha esperança\n\nÉ na música que eu me refiro\nÀs palmas e ritmos da minha terra\nSobre o samba, o zouk e o baile\nTudo que eu queria tinha tempo\n\nÉ nos olhares que eu me lembro\nDo meu primeiro beijo, da nossa risada\nDe cada gesto que era sincero\nQue agora só existe como memória\n\nÉ no ar fresco da cidadezinha\nEm que as ruas eram nossos campos de futebol\nOnde tín
# ...
# 45                                                                                                                                                                                                                                                                                                                                                                                                                  s         s ss           é                                                                                           s    s                                      s     s                s                                           s                     s                                                                         s                         s                             s     s         é        s               s
# 46                                                                                                                                                                                                                                            s  '            s                   s            s s ss    s                       s     s                                                s              s                      s  s     s                   s                                                     s     ss       s                    s    ss           ss                  s                    s   ss      s     s                 s      s                                               s  s     s           s                     s s    s     s    s            s              s       s                  s            s      s     s
# 47                                                                                                                                                                                                                                                                                                                                                                                   s        s              é                                     s  s     s               s                                                                                            s                                                 s   s ss     é                s     s             s       s      ss s                     s          s   s      s           s                        s     s               és   s      s    s                      s  s     s s
# 48                                                                                                                                                                                                                                                                                                    s         s       s             s      s s                   s                                                                                                                                                         s   é        s  s      s       s                              s         s       s             s        s                                       s          s   s             é      s                   é            s                            é    é       s                             s                      s s      s
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                      s              s         s               s              s            s s       s            s         s      s              s            s                s              s                                    s       s             s         é   ss                        s ss    s      s s           s                                          s                  s              s          s
# 50                                                                                                                                                                                                                                                                              s          s     s      s                                   s    s         s                                      s            s                      s                s s                  s          s            s     s      s  s       s       s s   s             s   é s        s   é  s         s   é   s    s                      s   é s        s   é                             s   s                   s                   s    s           s                      s  s   ss s    s   é   s    é                             s        é                é   s
# 51                                                                                                                                                                                                                                   s                 s            s             s               s    s                            s      s                                         s           s     s     s   s      s    s                                                                                  s       s              s      s   s                    s      s                                     s                         s                    s          s         ss          s                 s   s    s        s  s       s          s        s s      s            s         s         ss         s  s    s s                  s
# 52                                                                                                                                                                                                                                                            s                             s     s        s                    s'                   s                             ss        ss    è  à        s                   s       s                s                     è                                                                                     s      '    s                                                  ù            s                                                                             è   ù                         s                                                              s            '         s ss
# 53                                                                                                                                                                                                                                             '         s                    ss                                                             s                                        s           s             '                                è s                              s                        ù                                      s          s          s                    à        s        s                              s                    s  s                 s      s                s          s           s            s        s                           ù    s              s                             s             ù
#
#                                                                                                                                         testo_it
# 0                                                                                            s s ' s è s s s s s à s s ' s ù s ù s è s s s s s é
# 1                                                                                                s s s s s s s s s s s s s s s s s s s s s s s s
# 2                                                                                          ' s ' s s è ò s s s s ò ' s ' s ' s s è ò s ' s ' s s
# 3                                                                                               s s ' ' è s s ' s è ss s ù s s ss s s s' ' è s s
# 4                                                                                            s s s s s 'è s s s s s s s s ' s s s s s s s s s 'è
# 5                                                                                            s s s ss s s s s s à s s s ss s è ù s s ì s s s s s
# 6                                                                                                      ' s s s s s s s ' s ù s ' s ì ì s à è s s
# 7                                                                              s è s à s s ' s s s è s s ' s ss s è s s s s è s s s s è s s s ss
# 8                                                                                        s s s s s ù 'è s s s s s s s s s s s s s s s s sì s s s
# 9                                                  s s s w s w ss s ' s w 's w ' s w s s ss s s s w ss s s ' s s s s w w s s s s w s w s s ' w w
# 10                                             s ' w w s s w s s w ' w s s s w s s w w w s s w ss s s s w s s s s s s w w ' s s s sw s w s s s s
# 11  s s s s w s s s w s s s s s s s s s s w s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s ssss
# 12                                 s s s w ' s w s s s s s s s w ' s s s s s s s s s s s s w ' s w ss s s s s w ws s s w s s s s s s s w s w s s
# 13                         w w s s s s w s w s w ' s w s s s s s s s s s s s s s w ' s s w s s s s s s w ' s s s s w ' s w ' w ' s s w ' s w w '
# 14                             s s ss s s s s s s s s s s s s s w s w w ' w s s s s s s s w s s s ss s s s s s s s s s s s s s s s s s w w ' s w
# 15                                             s s w s s sw s ws ss s s w w s s w s s w s s s s s w s sw s ws s s ' w ' w w w w s s sw s s s w s
# 16                                                                                                                                       I ss'ws
# 17           s w s s w s s s sw s w w s s s w s s s s s s s w w s ws s s s s s w s s s sw s w w s s w s s s w w s s s s s s s w s s s sw s w w s
# 18                                                                                     s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 19                                                                                         s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 20                                                                                                     s s s s s s s s s s s s s s s s s s s s s
# 21                                                                   s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 22                                                                   s s s ss ss s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 23                                                                     s s s s s s s é s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 24                                                                 é s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s
# 25                                                                                                                     ss ssssssssssssssssssssss
# 26                                                                                         ' s s s s s s s s ss s s s s s sss s s ss ' à s s s s
# 27                                                                                                 s s s s s s s s s s s s s s s s s s s s s s s
# 28                                                 s s s s s s s s s s s s s s s s s s s s s s s s w ' s w w ' s s s s s s s w ss s s s s ws s s
# 29                                                                                               s s s sss s s s s s s è ss s ò s s s ss s s s ù
# 30                                                                                       s s s s s s s s s ss ss s è s s s s s s s s s s s s s s
# 31                                             s s s sw s s s w s s w ' s w s w ' s s s s w w ' w s s w w s s s sw s s s w s s s w ' s w s w ' s
# 32                               s s s w ' w ' s s s s s s s s s w s s s s s s w s s s s s s w ' w ' s s s s s w s s s w w s s s s w ' s s w s w
# 33                                                                                            s s è à s s è ss s s ' s s s ' s s s s s s s s s s
# 34                                  s w s ss s s s w s w s s s s w w s w s s s w w w w s sss s s s s s w s s s s s s w s s w s s s w w ' s w s w
# 35                                                                                                            ssssssssssssssssssàèssssssssss'sss
# 36                                                                       vestiti vestiti vestiti vestiti vestiti vestiti vestiti vestiti vestiti
# 37                                                                                                                                 sssssswssssss
# 38                                                                                        é s s s s é s s s s s s s s ss s s s s s s s é s é s s
# 39                                                                                            's s s w s à à à è w s iwe è ì à é s é ò ù à w ò ù
# 40                                                                                                                                         sssss
# 41                    w w s s w s s s s w s s s w s s s s s s s s s w ' s w ' w s s w s s s w s w ss s s s s s w s s s s w s s w s s w ' s w s s
# 42                                                            s s é s s s s ss é s s s s s s s s ss s s é às s s s é s ss s s s s s s s s ss s s
# 43                             s s è s s s s é s s è s s s'é s s s s s s s s s s s s ' s ' s ' ' s s s è à s s s s és s s s'é ' ss s s s s s è s
# 44                                                                               s s s s s s s s s ss s s ss s s s s s s s s s s s s s s s s s s
# 45                                                                                                                    s ss é s s s s s s s s é s
# 46                                                                 s ' s s s ss s s s s s s s s ss s ss ss ss ss s s s s s s s s s s s s s s s s
# 47                                                                                       s s é s s s s s ss é s s s ss s s s s s s s s s s s s s
# 48                                                                                                       ssssssssssssssssssssssssssssssissssssss
# 49                                                                                             s s s s s s s s s s s s s s s é ss ss s s s s s s
# 50                                              s s s s s s s s s s s s s s s s s s s é s s é s é s s é s s s s s s s s s ss s s é s é s é é é s
# 51                                                                  s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s s ss s s s s
# 52                                                                                              s s s s' ss ss è à s s s s è ' s ù s è ù s ' s s
# 53                                                                                         ' s ss s s ' è s sù s s à s s s s s s s s s s ù s s ù

# %% [markdown]
# ## 7. Raccolta del corpus reale tramite Genius API ufficiale
#
# Serve un token gratuito: vai su [genius.com/api-clients](https://genius.com/api-clients), crea una "API Client" (bastano nome e sito web fittizio, es. il tuo repo GitHub), poi genera un "Client Access Token" dalla pagina dell'app creata. Incolla il token quando richiesto dalla cella seguente (non viene salvato nel notebook — meglio ancora, salvalo nei Secrets di Colab col nome `GENIUS_ACCESS_TOKEN`).
#
# Anche qui: **se `testi_reali.csv` esiste già, non serve nemmeno il token** — la cella salta direttamente al caricamento da file.

# %%
import os

PERCORSO_CSV_REALI = "testi_reali.csv"

if not os.path.exists(PERCORSO_CSV_REALI):
    GENIUS_ACCESS_TOKEN = None
    try:
        from google.colab import userdata
        GENIUS_ACCESS_TOKEN = userdata.get("GENIUS_ACCESS_TOKEN")
        print("Token caricato dai Secrets di Colab.")
    except Exception:
        pass

    if not GENIUS_ACCESS_TOKEN:
        import getpass
        print("Secret non trovato: inseriscilo manualmente qui sotto (scrivi e premi Invio).")
        GENIUS_ACCESS_TOKEN = getpass.getpass("Genius API access token: ")

    import lyricsgenius
    genius = lyricsgenius.Genius(
        GENIUS_ACCESS_TOKEN, remove_section_headers=True, skip_non_songs=True,
        timeout=15
    )
else:
    print(f"{PERCORSO_CSV_REALI} gia presente: token non necessario, si carica direttamente il file.")
# Out:
# Secret non trovato: inseriscilo manualmente qui sotto (scrivi e premi Invio).
# Genius API access token: ··········

# %%
import pandas as pd
import os
import requests

FORZA_RIRACCOLTA = False
PERCORSO_CSV_REALI = "testi_reali.csv"

if os.path.exists(PERCORSO_CSV_REALI) and not FORZA_RIRACCOLTA:
    df_real = pd.read_csv(PERCORSO_CSV_REALI)
    print(f"Caricati {len(df_real)} testi reali da {PERCORSO_CSV_REALI}.")
else:
    # Corpus alternativo tramite API pubblica OVH senza API key
    brani = [
        ("trap italiana", "Sfera Ebbasta", "Cupido"),
        ("trap italiana", "Capo Plaza", "Tesla"),
        ("trap italiana", "Lazza", "Cenere"),
        ("pop anglosassone", "Taylor Swift", "Blank Space"),
        ("pop anglosassone", "Ed Sheeran", "Shape of You"),
        ("pop anglosassone", "Dua Lipa", "Levitating"),
        ("reggaeton", "Bad Bunny", "Tití Me Preguntó"),
        ("reggaeton", "Daddy Yankee", "Gasolina"),
        ("reggaeton", "Karol G", "PROVENZA"),
        ("K-pop", "BTS", "Dynamite"),
        ("K-pop", "BLACKPINK", "Pink Venom"),
        ("K-pop", "Stray Kids", "MANIAC"),
        ("afrobeats", "Burna Boy", "Last Last"),
        ("afrobeats", "Wizkid", "Essence"),
        ("afrobeats", "Davido", "Unavailable"),
        ("fado", "Amália Rodrigues", "Fado Português"),
        ("fado", "Mariza", "Gente da Minha Terra"),
        ("fado", "Ana Moura", "Desfado"),
    ]

    real_records = []
    headers = {'User-Agent': 'Mozilla/5.0'}

    for genere, artista, titolo in brani:
        try:
            url = f"https://api.lyrics.ovh/v1/{artista}/{titolo}"
            r = requests.get(url, headers=headers, timeout=10)
            if r.status_code == 200:
                data = r.json()
                testo = data.get("lyrics", "")
                if testo:
                    real_records.append({
                        "genere": genere, "artista": artista,
                        "titolo": titolo, "testo": testo, "fonte": "corpus_reale"
                    })
                    print(f"OK: {artista} - {titolo}")
            else:
                print(f"Non trovato: {artista} - {titolo}")
        except Exception as e:
            print(f"Errore con {artista} - {titolo}: {e}")

    df_real = pd.DataFrame(real_records)
    df_real.to_csv(PERCORSO_CSV_REALI, index=False)
    print(f"\nRaccolti {len(df_real)} testi reali e salvati in {PERCORSO_CSV_REALI}.")
# Out:
# OK: Sfera Ebbasta - Cupido
# OK: Capo Plaza - Tesla
# OK: Lazza - Cenere
# OK: Taylor Swift - Blank Space
# OK: Ed Sheeran - Shape of You
# OK: Dua Lipa - Levitating
# OK: Bad Bunny - Tití Me Preguntó
# OK: Daddy Yankee - Gasolina
# OK: Karol G - PROVENZA
# OK: BTS - Dynamite
# OK: BLACKPINK - Pink Venom
# OK: Stray Kids - MANIAC
# OK: Burna Boy - Last Last
# OK: Wizkid - Essence
# OK: Davido - Unavailable
# Non trovato: Amália Rodrigues - Fado Português
# Non trovato: Mariza - Gente da Minha Terra
# OK: Ana Moura - Desfado
#
# Raccolti 16 testi reali e salvati in testi_reali.csv.

# %% [markdown]
# ## 8. Preprocessing e normalizzazione linguistica
#
# I generi coprono lingue diverse (italiano, inglese, spagnolo, coreano, portoghese...). Per rendere confrontabili gli embedding, i testi non italiani vengono tradotti in italiano con `deep-translator` (nessuna chiave richiesta) — un passaggio esplicito da discutere come possibile limite: la traduzione stessa potrebbe introdurre un ulteriore appiattimento, da tenere distinto da quello attribuibile alla generazione.

# %%
import re
import time
from langdetect import detect
from deep_translator import GoogleTranslator

PERCORSO_CSV_GENERATI_IT = "testi_generati_it.csv"
PERCORSO_CSV_REALI_IT = "testi_reali_it.csv"

def pulisci_testo(testo):
    if not isinstance(testo, str):
        return ""
    t = testo.lower()
    t = re.sub(r"\[.*?\]", " ", t)         # CORRETTO: singolo backslash -> classi regex vere
    t = re.sub(r"[^\w\sàèéìòù']", " ", t)  # CORRETTO
    t = re.sub(r"\d+", " ", t)               # CORRETTO
    t = re.sub(r"\s+", " ", t).strip()       # CORRETTO
    return t

def traduci_in_italiano(testo, max_tentativi=3):
    if not isinstance(testo, str) or len(testo.strip()) == 0:
        return testo
    try:
        lingua = detect(testo)
    except Exception:
        lingua = "unknown"
    if lingua == "it":
        return testo
    for tentativo in range(max_tentativi):
        try:
            risultato = GoogleTranslator(source="auto", target="it").translate(testo[:4500])
            # Validazione: scarta risposte che sembrano pagine di errore invece di traduzioni
            # (il bug precedente le salvava come se fossero traduzioni valide)
            if risultato and "error" not in risultato.lower()[:20] and len(risultato.strip()) > 5:
                return risultato
        except Exception as e:
            print(f"Tentativo {tentativo + 1}/{max_tentativi} fallito: {e}")
        time.sleep(2 * (tentativo + 1))  # backoff progressivo tra i tentativi
    print("Traduzione fallita dopo piu tentativi: testo mantenuto non tradotto (verra escluso dal confronto).")
    return None  # None invece del testo grezzo: lo si potra escludere esplicitamente dall'analisi

# NB: FORZA la rigenerazione, perche i CSV *_it.csv esistenti sul disco sono quelli
# prodotti dal bug (regex rotta + errori Google salvati come traduzioni) e vanno rifatti.
FORZA_RIGENERAZIONE_TRADUZIONE = True

if os.path.exists(PERCORSO_CSV_GENERATI_IT) and os.path.exists(PERCORSO_CSV_REALI_IT) and not FORZA_RIGENERAZIONE_TRADUZIONE:
    df_generated = pd.read_csv(PERCORSO_CSV_GENERATI_IT)
    df_real = pd.read_csv(PERCORSO_CSV_REALI_IT)
    print("Testi puliti/tradotti gia presenti su disco: ricaricati senza rifare pulizia/traduzione.")
else:
    df_generated["testo_pulito"] = df_generated["testo"].apply(pulisci_testo)
    df_real["testo_pulito"] = df_real["testo"].apply(pulisci_testo)

    df_generated["testo_it"] = df_generated["testo_pulito"].apply(traduci_in_italiano)
    df_real["testo_it"] = df_real["testo_pulito"].apply(traduci_in_italiano)

    n_falliti_gen = df_generated["testo_it"].isna().sum()
    n_falliti_reali = df_real["testo_it"].isna().sum()
    if n_falliti_gen or n_falliti_reali:
        print(f"ATTENZIONE: {n_falliti_gen} testi generati e {n_falliti_reali} testi reali "
              f"non tradotti dopo i tentativi: verranno esclusi dal calcolo degli embedding.")
    df_generated = df_generated.dropna(subset=["testo_it"]).reset_index(drop=True)
    df_real = df_real.dropna(subset=["testo_it"]).reset_index(drop=True)

    df_generated.to_csv(PERCORSO_CSV_GENERATI_IT, index=False)
    df_real.to_csv(PERCORSO_CSV_REALI_IT, index=False)
    print("Pulizia e traduzione completate (con validazione) e salvate su disco.")

# Controllo di sanita: se questo stampa frasi con solo 's'/'w' isolate, la pulizia e ancora rotta.
print("\nEsempio di verifica (prime 200 battute):")
print(df_generated["testo_pulito"].iloc[0][:200])
# Out:
# Traduzione fallita dopo piu tentativi: testo mantenuto non tradotto (verra escluso dal confronto).
# Traduzione fallita dopo piu tentativi: testo mantenuto non tradotto (verra escluso dal confronto).
# ATTENZIONE: 2 testi generati e 0 testi reali non tradotti dopo i tentativi: verranno esclusi dal calcolo degli embedding.
# Pulizia e traduzione completate (con validazione) e salvate su disco.
#
# Esempio di verifica (prime 200 battute):
# chorus baby tu sei l'amore che ho cercato per tutto questo tempo ora è la mia vita ti sento nelle mie vene ti vedo in ogni cosa non potrei vivere senza di te verse sognavo di trovare qualcosa di diver

# %% [markdown]
# ## 9. Embedding semantici e similarità tra generi

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import seaborn as sns
import matplotlib.pyplot as plt

modello_embedding = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

def embedding_medio_per_genere(df, colonna_testo, colonna_gruppo):
    medie = {}
    for gruppo, sotto_df in df.groupby(colonna_gruppo):
        testi = sotto_df[colonna_testo].dropna().tolist()
        if not testi:
            continue
        emb = modello_embedding.encode(testi)
        medie[gruppo] = emb.mean(axis=0)
    return medie

emb_generati = embedding_medio_per_genere(df_generated, "testo_it", "genere")
emb_reali = embedding_medio_per_genere(df_real, "testo_it", "genere")

def matrice_similarita(embeddings_dict, ordine_generi):
    matrice = np.zeros((len(ordine_generi), len(ordine_generi)))
    for i, g1 in enumerate(ordine_generi):
        for j, g2 in enumerate(ordine_generi):
            v1, v2 = embeddings_dict[g1], embeddings_dict[g2]
            matrice[i, j] = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
    return pd.DataFrame(matrice, index=ordine_generi, columns=ordine_generi)

ordine_generi = [g for g in GENRES if g in emb_generati and g in emb_reali]
sim_generati = matrice_similarita(emb_generati, ordine_generi)
sim_reali = matrice_similarita(emb_reali, ordine_generi)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.heatmap(sim_generati, annot=True, cmap="coolwarm", ax=axes[0], vmin=0, vmax=1)
axes[0].set_title("Similarita tra generi - testi generati")
sns.heatmap(sim_reali, annot=True, cmap="coolwarm", ax=axes[1], vmin=0, vmax=1)
axes[1].set_title("Similarita tra generi - corpus reale")
plt.tight_layout()
plt.savefig("similarita_generi.png", dpi=150)
plt.show()
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  471MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 9.08MB
# tokenizer.json: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## 10. Verifica statistica dell'ipotesi

# %%
from scipy.stats import wilcoxon

idx_upper = np.triu_indices_from(sim_generati.values, k=1)
valori_generati = sim_generati.values[idx_upper]
valori_reali = sim_reali.values[idx_upper]

print(f"Similarita media tra generi - testi generati: {valori_generati.mean():.3f}")
print(f"Similarita media tra generi - corpus reale:    {valori_reali.mean():.3f}")

statistica, p = wilcoxon(valori_generati, valori_reali, alternative="greater")
print(f"\nTest di Wilcoxon (H2: generati > reali): statistica={statistica:.2f}, p-value={p:.4f}")
# p < 0.05 -> le coppie di generi sono significativamente piu simili tra loro nei testi
# generati rispetto al corpus reale: supporto per H2 (appiattimento del modello).
# Out:
# Similarita media tra generi - testi generati: 0.875
# Similarita media tra generi - corpus reale:    0.617
#
# Test di Wilcoxon (H2: generati > reali): statistica=120.00, p-value=0.0000
